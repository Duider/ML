# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab

# %%
juegos = pd.read_csv("../arch/video_juegos_populares.csv")      
juegos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7505 entries, 0 to 7504
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          7505 non-null   int64
#  1   Name          7505 non-null   object
#  2   Platform      7505 non-null   object
#  3   Year          7505 non-null   int64
#  4   Genre         7505 non-null   object
#  5   Publisher     7501 non-null   object
#  6   NA_Sales      7505 non-null   float64
#  7   EU_Sales      7505 non-null   float64
#  8   JP_Sales      7505 non-null   float64
#  9   Other_Sales   7505 non-null   float64
#  10  Global_Sales  7505 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 645.1+ KB

# %%
juegos
# Out:
#        Rank                                               Name Platform  Year  \
# 0         1                                         Wii Sports      Wii  2006
# 1         2                                  Super Mario Bros.      NES  1985
# 2         3                                     Mario Kart Wii      Wii  2008
# 3         4                                  Wii Sports Resort      Wii  2009
# 4         5                           Pokemon Red/Pokemon Blue       GB  1996
# ...     ...                                                ...      ...   ...
# 7500  14930                           America Oudan Ultra-Quiz      SAT  1995
# 7501  15188        Shippuu Mahou Daisakusen: Kingdom-Grandprix      SAT  1996
# 7502  15259                            Pebble Beach Golf Links      SAT  1994
# 7503  15292  NightTruth: Explanation of the Paranormal - Th...      SAT  1996
# 7504  15349                                             Code R      SAT  1998
#
# ...

# %%
juegos.sort_values("Year", ascending=False)
# Out:
#        Rank                                               Name    Platform  \
# 2670   5698                             LEGO Marvel's Avengers         PS3
# 2532   5385                             LEGO Marvel's Avengers        X360
# 6561  14971                                     Teddy Together         3DS
# 5827  12956                                    Culdcept Revolt         3DS
# 6289  14180  Nobunaga's Ambition: Sphere of Influence - Sen...         PS3
# ...     ...                                                ...         ...
# 155     259                                          Asteroids  Atari_2600
# 3206   6898                                           Checkers  Atari_2600
# 1337   2671                                             Boxing  Atari_2600
# 2525   5368                                            Freeway  Atari_2600
# 971    1971                                           Defender  Atari_2600
#
# ...

# %%
juegos_2016 = juegos.loc[juegos["Year"]==2016] 
juegos_2016
# Out:
#        Rank                                               Name Platform  Year  \
# 789    1570                                      Yokai Watch 3      3DS  2016
# 1224   2450                              Kirby: Planet Robobot      3DS  2016
# 1587   3223                      Dragon Quest Monsters Joker 3      3DS  2016
# 1782   3650                                   Yokai Sangokushi      3DS  2016
# 2065   4263        Mario & Sonic at the Rio 2016 Olympic Games      3DS  2016
# ...     ...                                                ...      ...   ...
# 6886  15985  Super Battle For Money Sentouchuu: Kyuukyoku n...      3DS  2016
# 6893  16001                     One Piece: Daikaizoku Coliseum      3DS  2016
# 6906  16039                   Utawarerumono: Futari no Hakuoro      PS3  2016
# 6972  16239                     Batman: A Telltale Game Series      PS3  2016
# 7045  16475                Azure Striker Gunvolt: Striker Pack      3DS  2016
#
# ...

# %%
plt.hist(juegos_2016["Global_Sales"], edgecolor="black", linewidth=2)
# Out:
# (array([57.,  8.,  4.,  2.,  2.,  0.,  1.,  0.,  0.,  1.]),
#  array([0.01 , 0.136, 0.262, 0.388, 0.514, 0.64 , 0.766, 0.892, 1.018,
#         1.144, 1.27 ]),
#  <BarContainer object of 10 artists>)

# %%
juegos_populares_2016 = juegos_2016.loc[juegos_2016["Global_Sales"]>0.7]
juegos_populares_2016
# Out:
#       Rank                   Name Platform  Year   Genre Publisher  NA_Sales  \
# 789   1570          Yokai Watch 3      3DS  2016  Action   Level 5      0.00
# 1224  2450  Kirby: Planet Robobot      3DS  2016  Action  Nintendo      0.26
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 789        0.0      1.27         0.00          1.27
# 1224       0.1      0.44         0.04          0.85

# %%
x = juegos["Year"]
y = juegos["Global_Sales"]

fig, ax = plt.subplots()
plt.title("Ventas globales a través de los años")
ax.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
juegos.sort_values("Global_Sales", ascending=False)
# Out:
#        Rank                                         Name Platform  Year  \
# 0         1                                   Wii Sports      Wii  2006
# 1         2                            Super Mario Bros.      NES  1985
# 2         3                               Mario Kart Wii      Wii  2008
# 3         4                            Wii Sports Resort      Wii  2009
# 4         5                     Pokemon Red/Pokemon Blue       GB  1996
# ...     ...                                          ...      ...   ...
# 6954  16181                                  Putty Squad      PS3  2013
# 6955  16182  Sega Golf Club: Miyazato San Kyoudai Naizou      PS3  2006
# 6956  16184                         Resistance Dual Pack      PS3  2011
# 6957  16191                             Toro to Morimori      PS3  2009
# 6966  16218                Tsukigime Ranko's Longest Day      PS3  2014
#
#              Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...
