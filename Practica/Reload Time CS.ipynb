# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
reload_time =  pd.read_csv("../arch/armasCsReloadTime.csv")
reload_time
# Out:
#              Pistols  Deploy Time  Reload\n(Clip Ready)  Reload\n(Fire Ready)
# 0       Desert Eagle         1.00                  0.87                  2.20
# 1        R8 Revolver         1.17                  1.97                  2.27
# 2      Dual Berettas         1.00                  2.90                  3.77
# 3         Five-SeveN         1.00                  0.93                  2.27
# 4           Glock-18         1.10                  0.93                  2.27
# 5              P2000         1.00                  0.97                  2.27
# 6              USP-S         1.00                  0.97                  2.17
# 7               P250         1.00                  0.93                  2.27
# 8          CZ75 Auto         1.83           1.53 & 1.17           2.73 & 2.83
# 9              Tec-9         1.00                  1.33                  2.57
# 10               NaN          NaN                   NaN                   NaN
# ...

# %%
reload_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pistols              39 non-null     object
#  1   Deploy Time          39 non-null     object
#  2   Reload
# (Clip Ready)  39 non-null     object
#  3   Reload
# (Fire Ready)  39 non-null     object
# dtypes: object(4)
# memory usage: 1.5+ KB

# %%
reload_time = reload_time.dropna(thresh=2)
reload_time.reset_index(drop=True, inplace=True)
reload_time
# Out:
#              Pistols  Deploy Time  Reload\n(Clip Ready)  Reload\n(Fire Ready)
# 0       Desert Eagle         1.00                  0.87                  2.20
# 1        R8 Revolver         1.17                  1.97                  2.27
# 2      Dual Berettas         1.00                  2.90                  3.77
# 3         Five-SeveN         1.00                  0.93                  2.27
# 4           Glock-18         1.10                  0.93                  2.27
# 5              P2000         1.00                  0.97                  2.27
# 6              USP-S         1.00                  0.97                  2.17
# 7               P250         1.00                  0.93                  2.27
# 8          CZ75 Auto         1.83           1.53 & 1.17           2.73 & 2.83
# 9              Tec-9         1.00                  1.33                  2.57
# 10          Shotguns  Deploy Time  Reload\n(Clip Ready)  Reload\n(Fire Ready)
# ...

# %%
pd.to_numeric(reload_time["Reload\n(Clip Ready)"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File D:\Users\Tomi\Documents\Anaconda\lib\site-packages\pandas\_libs\lib.pyx:2369, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1.53 & 1.17"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.to_numeric(reload_time["Reload\n(Clip Ready)"])
#
# File D:\Users\Tomi\Documents\Anaconda\lib\site-packages\pandas\core\tools\numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# ...
