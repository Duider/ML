# %%
#https://www.youtube.com/watch?v=n98fnSEoRiM&list=PLUofJx5RUeFrAet3Y_eA0hBeYW50SZ4rZ&index=5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Cuando no es óptimo KMeans?
#Cuando los clusters tienen tamaños o densidades muy diferentes o cuando los individuos crean formas arbitrarias 
#o los individuos tienen ruido en sus datos

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Criterio de la inercia: Lo ideal es que los individuos dentro de un mismo clusters esten cercanos y la distancia entre
# clusters este bien marcada

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
...
